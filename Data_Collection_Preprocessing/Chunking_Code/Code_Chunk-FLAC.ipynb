# %%
import os
from pydub import AudioSegment
import io
import webrtcvad
import numpy as np
import wave


def flac_to_raw(flac_file):
    audio = AudioSegment.from_file(flac_file, format="flac")
    audio = audio.set_channels(1)
    audio = audio.set_sample_width(2)  
    audio = audio.set_frame_rate(16000)  
    
    raw_data = io.BytesIO()
    audio.export(raw_data, format="wav")
    raw_data.seek(0)
    
    with wave.open(raw_data, 'rb') as wf:
        sample_rate = wf.getframerate()
        samples = wf.readframes(wf.getnframes())
        samples = np.frombuffer(samples, dtype=np.int16)
        
    return sample_rate, samples


def vad_segment(samples, sample_rate):
    vad = webrtcvad.Vad(3)  
    frame_duration = 30  # ms
    frame_size = int(sample_rate * frame_duration / 1000) * 2 

    def frame_generator(samples, frame_size):
        for start in range(0, len(samples), frame_size // 2):  
            yield samples[start:start + (frame_size // 2)]

    def vad_collector(sample_rate, frames):
        buffer = b''
        segments = []
        for frame in frames:
            if len(frame) < frame_size // 2:
                continue
            frame_bytes = frame.astype(np.int16).tobytes()
            if vad.is_speech(frame_bytes, sample_rate):
                buffer += frame_bytes
            elif buffer:
                segments.append(buffer)
                buffer = b''
        if buffer:
            segments.append(buffer)
        return segments

    frames = frame_generator(samples, frame_size)
    segments = vad_collector(sample_rate, frames)
    
    print(f"Detected {len(segments)} speech chunks")
    return segments

def save_chunks(chunks, sample_rate, output_dir, base_filename='chunk'):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    silence_duration_ms = 500 
    silence_chunk = AudioSegment.silent(duration=silence_duration_ms, frame_rate=sample_rate)

    for i, chunk in enumerate(chunks):
        with io.BytesIO(chunk) as raw_data:
            audio_segment = AudioSegment.from_raw(raw_data, sample_width=2, frame_rate=sample_rate, channels=1)
            # Add silence padding to the beginning and end
            padded_audio_segment = silence_chunk + audio_segment + silence_chunk
            duration_seconds = len(padded_audio_segment) / 1000.0 

            if duration_seconds > 2: 
                output_path = os.path.join(output_dir, f'{base_filename}_{i}.flac')
                padded_audio_segment.export(output_path, format='flac')
                print(f"Saved chunk {i} as {output_path}, duration: {duration_seconds} seconds")
            else:
                print(f"Discarded chunk {i}, duration: {duration_seconds} seconds")


def process_file(flac_file, output_base_dir):
    base_filename = os.path.splitext(os.path.basename(flac_file))[0]
    output_dir = os.path.join(output_base_dir, base_filename)
    print(f"Processing file: {flac_file}")
    sample_rate, samples = flac_to_raw(flac_file)
    speech_chunks = vad_segment(samples, sample_rate)
    save_chunks(speech_chunks, sample_rate, output_dir, base_filename)

def process_input(input_path, output_base_dir):
    if os.path.isdir(input_path):
        flac_files = [os.path.join(input_path, file) for file in os.listdir(input_path) if file.endswith('.flac')]
        for flac_file in flac_files:
            process_file(flac_file, output_base_dir)
    elif os.path.isfile(input_path) and input_path.endswith('.flac'):
        process_file(input_path, output_base_dir)
    else:
        print("Invalid input. Please provide a directory containing FLAC files or a single FLAC file.")

# Example usage
if __name__ == "__main__":
    input_path = 'RFI\Speaker_10_vocals.flac'  
    output_base_dir = 'output_chunks'  
    process_input(input_path, output_base_dir)
# Out:
# Processing file: RFI\Speaker_10_vocals.flac
# Detected 82 speech chunks
# Saved chunk 0 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_0.flac, duration: 6.73 seconds
# Discarded chunk 1, duration: 1.15 seconds
# Saved chunk 2 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_2.flac, duration: 2.29 seconds
# Saved chunk 3 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_3.flac, duration: 5.02 seconds
# Saved chunk 4 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_4.flac, duration: 5.29 seconds
# Discarded chunk 5, duration: 1.12 seconds
# Saved chunk 6 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_6.flac, duration: 2.92 seconds
# Saved chunk 7 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_7.flac, duration: 2.38 seconds
# Discarded chunk 8, duration: 1.09 seconds
# Discarded chunk 9, duration: 1.45 seconds
# Saved chunk 10 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_10.flac, duration: 2.2 seconds
# Saved chunk 11 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_11.flac, duration: 2.11 seconds
# Discarded chunk 12, duration: 1.72 seconds
# Discarded chunk 13, duration: 1.93 seconds
# Discarded chunk 14, duration: 1.54 seconds
# Discarded chunk 15, duration: 1.15 seconds
# Saved chunk 16 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_16.flac, duration: 2.32 seconds
# Discarded chunk 17, duration: 1.81 seconds
# Saved chunk 18 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_18.flac, duration: 2.32 seconds
# Saved chunk 19 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_19.flac, duration: 2.83 seconds
# Saved chunk 20 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_20.flac, duration: 2.8 seconds
# Saved chunk 21 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_21.flac, duration: 3.07 seconds
# Saved chunk 22 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_22.flac, duration: 3.07 seconds
# Saved chunk 23 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_23.flac, duration: 3.04 seconds
# Saved chunk 24 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_24.flac, duration: 2.56 seconds
# Saved chunk 25 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_25.flac, duration: 3.31 seconds
# Saved chunk 26 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_26.flac, duration: 4.54 seconds
# Saved chunk 27 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_27.flac, duration: 4.0 seconds
# Saved chunk 28 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_28.flac, duration: 3.37 seconds
# Saved chunk 29 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_29.flac, duration: 6.7 seconds
# Saved chunk 30 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_30.flac, duration: 8.26 seconds
# Discarded chunk 31, duration: 1.42 seconds
# Discarded chunk 32, duration: 1.33 seconds
# Saved chunk 33 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_33.flac, duration: 8.77 seconds
# Saved chunk 34 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_34.flac, duration: 7.06 seconds
# Discarded chunk 35, duration: 1.99 seconds
# Discarded chunk 36, duration: 1.81 seconds
# Saved chunk 37 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_37.flac, duration: 11.41 seconds
# Discarded chunk 38, duration: 1.24 seconds
# Saved chunk 39 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_39.flac, duration: 4.12 seconds
# Discarded chunk 40, duration: 1.87 seconds
# Saved chunk 41 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_41.flac, duration: 2.08 seconds
# Saved chunk 42 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_42.flac, duration: 2.8 seconds
# Discarded chunk 43, duration: 1.78 seconds
# Saved chunk 44 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_44.flac, duration: 7.57 seconds
# Discarded chunk 45, duration: 1.39 seconds
# Discarded chunk 46, duration: 1.18 seconds
# Saved chunk 47 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_47.flac, duration: 3.13 seconds
# Saved chunk 48 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_48.flac, duration: 2.8 seconds
# Saved chunk 49 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_49.flac, duration: 2.5 seconds
# Saved chunk 50 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_50.flac, duration: 3.43 seconds
# Saved chunk 51 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_51.flac, duration: 2.17 seconds
# Saved chunk 52 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_52.flac, duration: 2.77 seconds
# Discarded chunk 53, duration: 1.48 seconds
# Saved chunk 54 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_54.flac, duration: 5.08 seconds
# Discarded chunk 55, duration: 1.15 seconds
# Saved chunk 56 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_56.flac, duration: 5.05 seconds
# Saved chunk 57 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_57.flac, duration: 3.22 seconds
# Discarded chunk 58, duration: 1.81 seconds
# Discarded chunk 59, duration: 1.36 seconds
# Saved chunk 60 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_60.flac, duration: 2.14 seconds
# Discarded chunk 61, duration: 1.9 seconds
# Saved chunk 62 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_62.flac, duration: 3.61 seconds
# Discarded chunk 63, duration: 1.09 seconds
# Saved chunk 64 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_64.flac, duration: 3.67 seconds
# Saved chunk 65 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_65.flac, duration: 3.7 seconds
# Saved chunk 66 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_66.flac, duration: 7.84 seconds
# Saved chunk 67 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_67.flac, duration: 3.82 seconds
# Saved chunk 68 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_68.flac, duration: 3.28 seconds
# Discarded chunk 69, duration: 1.63 seconds
# Saved chunk 70 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_70.flac, duration: 3.88 seconds
# Discarded chunk 71, duration: 1.24 seconds
# Saved chunk 72 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_72.flac, duration: 3.37 seconds
# Saved chunk 73 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_73.flac, duration: 2.38 seconds
# Saved chunk 74 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_74.flac, duration: 3.07 seconds
# Saved chunk 75 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_75.flac, duration: 3.19 seconds
# Saved chunk 76 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_76.flac, duration: 2.89 seconds
# Saved chunk 77 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_77.flac, duration: 2.32 seconds
# Saved chunk 78 as output_chunks\Speaker_10_vocals\Speaker_10_vocals_78.flac, duration: 3.58 seconds
# Discarded chunk 79, duration: 1.09 seconds
# Discarded chunk 80, duration: 1.09 seconds
# Discarded chunk 81, duration: 1.09 seconds
