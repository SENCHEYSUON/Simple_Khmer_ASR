# %%
import os
from yt_dlp import YoutubeDL


from google.colab import drive
drive.mount('/content/drive')

output_dir = '/content/drive/MyDrive/a'


def download_youtube_audio(youtube_url, output_dir):
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': os.path.join(output_dir, '%(title)s.%(ext)s'),
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'flac',
            'preferredquality': '192',
        }],
    }

    with YoutubeDL(ydl_opts) as ydl:
        ydl.download([youtube_url])


youtube_url = 'https://youtu.be/Ov6RRFDR5X8?si=937vuOF6U6dxDH1v'  

download_youtube_audio(youtube_url, output_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [youtube] Extracting URL: https://youtu.be/Ov6RRFDR5X8?si=937vuOF6U6dxDH1v
# [youtube] Ov6RRFDR5X8: Downloading webpage
# [youtube] Ov6RRFDR5X8: Downloading ios player API JSON
# [youtube] Ov6RRFDR5X8: Downloading web creator player API JSON
# [youtube] Ov6RRFDR5X8: Downloading player 7fe34188
# [youtube] Ov6RRFDR5X8: Downloading m3u8 information
# [info] Ov6RRFDR5X8: Downloading 1 format(s): 251
# [download] Destination: /content/drive/MyDrive/a/ទស្សនយុវជនជុំវិញកិច្ចសហប្រតិបត្តិការតំបន់ត្រីកោណអភិវឌ្ឍន៍ កម្ពុជា-ឡាវ-វៀតណាម (CLV-DTA).webm
# [download] 100% of   37.18MiB in 00:00:03 at 10.41MiB/s
# [ExtractAudio] Destination: /content/drive/MyDrive/a/ទស្សនយុវជនជុំវិញកិច្ចសហប្រតិបត្តិការតំបន់ត្រីកោណអភិវឌ្ឍន៍ កម្ពុជា-ឡាវ-វៀតណាម (CLV-DTA).flac
# Deleting original file /content/drive/MyDrive/a/ទស្សនយុវជនជុំវិញកិច្ចសហប្រតិបត្តិការតំបន់ត្រីកោណអភិវឌ្ឍន៍ កម្ពុជា-ឡាវ-វៀតណាម (CLV-DTA).webm (pass -k to keep)

# %%
script_code = """
import soundfile as sf
import torch
import os
import librosa
import numpy as np
import onnxruntime as ort
from pathlib import Path
from argparse import ArgumentParser
from tqdm import tqdm
import glob


class ConvTDFNet:
    def __init__(self, target_name, L, dim_f, dim_t, n_fft, hop=1024):
        super(ConvTDFNet, self).__init__()
        self.dim_c = 4
        self.dim_f = dim_f
        self.dim_t = 2**dim_t
        self.n_fft = n_fft
        self.hop = hop
        self.n_bins = self.n_fft // 2 + 1
        self.chunk_size = hop * (self.dim_t - 1)
        self.window = torch.hann_window(window_length=self.n_fft, periodic=True)
        self.target_name = target_name

        out_c = self.dim_c * 4 if target_name == "*" else self.dim_c

        self.freq_pad = torch.zeros([1, out_c, self.n_bins - self.dim_f, self.dim_t])
        self.n = L // 2

    def stft(self, x):
        x = x.reshape([-1, self.chunk_size])
        x = torch.stft(
            x,
            n_fft=self.n_fft,
            hop_length=self.hop,
            window=self.window,
            center=True,
            return_complex=True,
        )
        x = torch.view_as_real(x)
        x = x.permute([0, 3, 1, 2])
        x = x.reshape([-1, 2, 2, self.n_bins, self.dim_t]).reshape(
            [-1, self.dim_c, self.n_bins, self.dim_t]
        )
        return x[:, :, : self.dim_f]

    # Inversed Short-time Fourier transform (STFT).
    def istft(self, x, freq_pad=None):
        freq_pad = (
            self.freq_pad.repeat([x.shape[0], 1, 1, 1])
            if freq_pad is None
            else freq_pad
        )
        x = torch.cat([x, freq_pad], -2)
        c = 4 * 2 if self.target_name == "*" else 2
        x = x.reshape([-1, c, 2, self.n_bins, self.dim_t]).reshape(
            [-1, 2, self.n_bins, self.dim_t]
        )
        x = x.permute([0, 2, 3, 1])
        x = x.contiguous()
        x = torch.view_as_complex(x)
        x = torch.istft(
            x, n_fft=self.n_fft, hop_length=self.hop, window=self.window, center=True
        )
        return x.reshape([-1, c, self.chunk_size])

class Predictor:
    def __init__(self, args):
        self.args = args
        self.model_ = ConvTDFNet(
            target_name="vocals",
            L=11,
            dim_f=args["dim_f"],
            dim_t=args["dim_t"],
            n_fft=args["n_fft"]
        )

        if torch.cuda.is_available():
            self.model = ort.InferenceSession(args['model_path'], providers=['CUDAExecutionProvider'])
        else:
            self.model = ort.InferenceSession(args['model_path'], providers=['CPUExecutionProvider'])

    def demix(self, mix):
        samples = mix.shape[-1]
        margin = self.args["margin"]
        chunk_size = self.args["chunks"] * 44100

        assert not margin == 0, "margin cannot be zero!"

        if margin > chunk_size:
            margin = chunk_size

        segmented_mix = {}

        if self.args["chunks"] == 0 or samples < chunk_size:
            chunk_size = samples

        counter = -1
        for skip in range(0, samples, chunk_size):
            counter += 1
            s_margin = 0 if counter == 0 else margin
            end = min(skip + chunk_size + margin, samples)
            start = skip - s_margin
            segmented_mix[skip] = mix[:, start:end].copy()
            if end == samples:
                break

        sources = self.demix_base(segmented_mix, margin_size=margin)
        return sources

    def demix_base(self, mixes, margin_size):
        chunked_sources = []
        progress_bar = tqdm(total=len(mixes))
        progress_bar.set_description("Processing")

        for mix in mixes:
            cmix = mixes[mix]
            sources = []
            n_sample = cmix.shape[1]
            model = self.model_
            trim = model.n_fft // 2
            gen_size = model.chunk_size - 2 * trim
            pad = gen_size - n_sample % gen_size
            mix_p = np.concatenate(
                (np.zeros((2, trim)), cmix, np.zeros((2, pad)), np.zeros((2, trim))), 1
            )
            mix_waves = []
            i = 0
            while i < n_sample + pad:
                waves = np.array(mix_p[:, i : i + model.chunk_size])
                mix_waves.append(waves)
                i += gen_size

            mix_waves = torch.tensor(np.array(mix_waves), dtype=torch.float32)

            with torch.no_grad():
                _ort = self.model
                spek = model.stft(mix_waves)
                if self.args["denoise"]:
                    spec_pred = (
                        -_ort.run(None, {"input": -spek.cpu().numpy()})[0] * 0.5
                        + _ort.run(None, {"input": spek.cpu().numpy()})[0] * 0.5
                    )
                    tar_waves = model.istft(torch.tensor(spec_pred))
                else:
                    tar_waves = model.istft(
                        torch.tensor(_ort.run(None, {"input": spek.cpu().numpy() })[0])
                    )
                tar_signal = (
                    tar_waves[:, :, trim:-trim]
                    .transpose(0, 1)
                    .reshape(2, -1)
                    .numpy()[:, :-pad]
                )

                start = 0 if mix == 0 else margin_size
                end = None if mix == list(mixes.keys())[::-1][0] else -margin_size

                if margin_size == 0:
                    end = None

                sources.append(tar_signal[:, start:end])

                progress_bar.update(1)

            chunked_sources.append(sources)
        _sources = np.concatenate(chunked_sources, axis=-1)

        progress_bar.close()
        return _sources

    def predict(self, file_path):

        mix, rate = librosa.load(file_path, mono=False, sr=44100)

        if mix.ndim == 1:
            mix = np.asfortranarray([mix, mix])

        mix = mix.T
        sources = self.demix(mix.T)
        opt = sources[0].T

        return (mix - opt, opt, rate)

def main():
    parser = ArgumentParser(description="Ultimate Vocal Remover Inference CLI")
    parser.add_argument("inputs", nargs="+", type=Path, help="Source audio path or folder containing audio files")
    parser.add_argument("-o", "--output", type=Path, default=Path("separated"), help="Output folder")
    parser.add_argument("-m", "--model_path", type=Path, help="MDX Net ONNX Model path")
    parser.add_argument("-d", "--denoise", action="store_true", help="Enable denoising")
    parser.add_argument("-M", "--margin", type=int, default=44100, help="Margin")
    parser.add_argument("-c", "--chunks", type=int, default=15, help="Chunk size")
    parser.add_argument("-F", "--n_fft", type=int, default=6144)
    parser.add_argument("-t", "--dim_t", type=int, default=8)
    parser.add_argument("-f", "--dim_f", type=int, default=2048)

    args = parser.parse_args()
    dict_args = vars(args)

    os.makedirs(args.output, exist_ok=True)

    # Process each input which could be either a file or a folder
    for input_path in args.inputs:
        if input_path.is_dir():
            # Process all files in the directory
            file_paths = glob.glob(str(input_path / '*.flac'))  # Adjust the glob pattern if necessary
            for file_path in file_paths:
                file_path = Path(file_path)
                process_file(file_path, dict_args)
        else:
            # Process the single file
            process_file(input_path, dict_args)

def process_file(file_path, args):
    predictor = Predictor(args=args)
    vocals, no_vocals, sampling_rate = predictor.predict(file_path)
    filename = os.path.splitext(os.path.split(file_path)[-1])[0]
    sf.write(os.path.join(args["output"], filename + "_vocals.flac"), vocals, sampling_rate)

if __name__ == "__main__":
    main()
"""

with open('/content/drive/MyDrive/a/separate.py', 'w') as f:
    f.write(script_code)

# %%
# !python /content/drive/MyDrive/a/separate.py "/content/drive/MyDrive/a/ហេតុអ្វីបានជាក្រុមប្រឆាំងក្រៅស្រុក.flac" -o "/content/drive/MyDrive/e" -m "/content/drive/MyDrive/a/UVR-MDX-NET-Inst_Main.onnx"
# Out:
# Processing: 100% 217/217 [1:30:39<00:00, 25.06s/it]

# %%
from pydub import AudioSegment
import io
import webrtcvad
import numpy as np
import wave
import os
from google.colab import drive


drive.mount('/content/drive')


def flac_to_raw(flac_file):
    audio = AudioSegment.from_file(flac_file, format="flac")
    audio = audio.set_channels(1)  
    audio = audio.set_sample_width(2) 
    audio = audio.set_frame_rate(16000)  

    raw_data = io.BytesIO()
    audio.export(raw_data, format="wav")
    raw_data.seek(0)

    with wave.open(raw_data, 'rb') as wf:
        sample_rate = wf.getframerate()
        samples = wf.readframes(wf.getnframes())
        samples = np.frombuffer(samples, dtype=np.int16)

    return sample_rate, samples


def vad_segment(samples, sample_rate, frame_duration_ms=30, padding_duration_ms=500, max_chunk_duration=9):
    vad = webrtcvad.Vad(3)
    frame_size = int(sample_rate * frame_duration_ms / 1000)
    max_chunk_samples = sample_rate * max_chunk_duration
    num_padding_frames = int(padding_duration_ms / frame_duration_ms)

    def frame_generator(samples, frame_size):
        for start in range(0, len(samples), frame_size):
            yield samples[start:start + frame_size]

    def vad_collector(sample_rate, frames):
        buffer = []
        triggered = False
        voiced_frames = []
        silence_frames = 0
        speech_segments = []

        for frame in frames:
            if len(frame) < frame_size:
                print("Skipping frame due to incorrect size.")
                continue

            frame_bytes = frame.tobytes()
            try:
                is_speech = vad.is_speech(frame_bytes, sample_rate)
            except Exception as e:
                print(f"Error processing frame: {e}")
                continue

            if is_speech:
                if not triggered:
                    triggered = True
                    buffer.extend(voiced_frames)
                    voiced_frames = []
                buffer.append(frame)
                silence_frames = 0
            else:
                if triggered:
                    buffer.append(frame)
                    silence_frames += 1
                    if silence_frames > num_padding_frames or len(buffer) * frame_size >= max_chunk_samples:
                        triggered = False
                        speech_segments.append(np.concatenate(buffer))
                        buffer = []
                else:
                    voiced_frames.append(frame)
                    if len(voiced_frames) > num_padding_frames:
                        voiced_frames = voiced_frames[1:]

        if buffer:
            speech_segments.append(np.concatenate(buffer))

        print(f"Detected {len(speech_segments)} speech chunks")
        return speech_segments

    frames = frame_generator(samples, frame_size)
    segments = vad_collector(sample_rate, frames)
    return segments


def contains_significant_speech(audio_segment, silence_threshold_db=-40, min_duration_ms=1000):
    duration_ms = len(audio_segment)
    if duration_ms < min_duration_ms:
        return False

    avg_dBFS = audio_segment.dBFS
    return avg_dBFS > silence_threshold_db

def save_chunks(chunks, sample_rate, output_dir='chunks', base_filename='p', max_duration_ms=9800, min_silence_db=-40):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    padding_silence = AudioSegment.silent(duration=500) 

    for i, chunk in enumerate(chunks):
        if len(chunk) > 0:
            with io.BytesIO(chunk.tobytes()) as raw_data:
                audio_segment = AudioSegment.from_raw(raw_data, sample_width=2, frame_rate=sample_rate, channels=1)

                if not contains_significant_speech(audio_segment, silence_threshold_db=min_silence_db):
                    print(f"Chunk {i} is silent and will be skipped.")
                    continue

                audio_segment = padding_silence + audio_segment + padding_silence

                while len(audio_segment) > max_duration_ms:
                    split_point = max_duration_ms

                    
                    for j in range(max_duration_ms - 1, max_duration_ms - 3000, -1):
                        if audio_segment[j-1:j+1].dBFS < min_silence_db:
                            split_point = j
                            break

                   
                    chunk_to_export = audio_segment[:split_point]
                    chunk_to_export.export(os.path.join(output_dir, f'{base_filename}_{i}.flac'), format='flac')
                    print(f"Saved chunk {i} as {base_filename}_{i}.flac") 
                    i += 1

                   
                    audio_segment = audio_segment[split_point:]

                if len(audio_segment) > 0:
                    audio_segment.export(os.path.join(output_dir, f'{base_filename}_{i}.flac'), format='flac')
                    print(f"Saved chunk {i} as {base_filename}_{i}.flac") # Changed this line


def main(flac_file):
    sample_rate, samples = flac_to_raw(flac_file)
    speech_chunks = vad_segment(samples, sample_rate)

   
    drive_folder = '/content/drive/MyDrive/l' 
    save_chunks(speech_chunks, sample_rate, output_dir=drive_folder)

# Example usage
if __name__ == "__main__":
    flac_file = '/content/drive/MyDrive/a/ទស្សនយុវជនជុំវិញកិច្ចសហប្រតិបត្តិការតំបន់ត្រីកោណអភិវឌ្ឍន៍ កម្ពុជា-ឡាវ-វៀតណាម (CLV-DTA).flac'  # Replace with your FLAC file path
    main(flac_file)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Skipping frame due to incorrect size.
# Detected 493 speech chunks
# Saved chunk 0 as p_0.flac
# Saved chunk 1 as p_1.flac
# Saved chunk 1 as p_1.flac
# Saved chunk 2 as p_2.flac
# Saved chunk 2 as p_2.flac
# Saved chunk 3 as p_3.flac
# Saved chunk 4 as p_4.flac
# Saved chunk 4 as p_4.flac
# Saved chunk 5 as p_5.flac
# Saved chunk 5 as p_5.flac
# Saved chunk 6 as p_6.flac
# Saved chunk 6 as p_6.flac
# Saved chunk 7 as p_7.flac
# Saved chunk 7 as p_7.flac
# Saved chunk 8 as p_8.flac
# Saved chunk 8 as p_8.flac
# Saved chunk 9 as p_9.flac
# Saved chunk 10 as p_10.flac
# Saved chunk 10 as p_10.flac
# Saved chunk 11 as p_11.flac
# Saved chunk 11 as p_11.flac
# Saved chunk 12 as p_12.flac
# Saved chunk 12 as p_12.flac
# Saved chunk 13 as p_13.flac
# Saved chunk 13 as p_13.flac
# Saved chunk 14 as p_14.flac
# Saved chunk 14 as p_14.flac
# Saved chunk 15 as p_15.flac
# Saved chunk 15 as p_15.flac
# Saved chunk 16 as p_16.flac
# Saved chunk 17 as p_17.flac
# Saved chunk 17 as p_17.flac
# Saved chunk 18 as p_18.flac
# Saved chunk 18 as p_18.flac
# Saved chunk 19 as p_19.flac
# Saved chunk 19 as p_19.flac
# Saved chunk 20 as p_20.flac
# Saved chunk 21 as p_21.flac
# Saved chunk 21 as p_21.flac
# Saved chunk 22 as p_22.flac
# Saved chunk 22 as p_22.flac
# Saved chunk 23 as p_23.flac
# Saved chunk 23 as p_23.flac
# Saved chunk 24 as p_24.flac
# Saved chunk 24 as p_24.flac
# Saved chunk 25 as p_25.flac
# Saved chunk 25 as p_25.flac
# Saved chunk 26 as p_26.flac
# Saved chunk 27 as p_27.flac
# Saved chunk 28 as p_28.flac
# Saved chunk 29 as p_29.flac
# Saved chunk 30 as p_30.flac
# Saved chunk 31 as p_31.flac
# Saved chunk 32 as p_32.flac
# Saved chunk 33 as p_33.flac
# Saved chunk 34 as p_34.flac
# Saved chunk 34 as p_34.flac
# Saved chunk 35 as p_35.flac
# Saved chunk 36 as p_36.flac
# Saved chunk 36 as p_36.flac
# Saved chunk 37 as p_37.flac
# Saved chunk 38 as p_38.flac
# Saved chunk 39 as p_39.flac
# Saved chunk 39 as p_39.flac
# Saved chunk 40 as p_40.flac
# Saved chunk 41 as p_41.flac
# Saved chunk 42 as p_42.flac
# Saved chunk 43 as p_43.flac
# Saved chunk 43 as p_43.flac
# Saved chunk 44 as p_44.flac
# Saved chunk 44 as p_44.flac
# Saved chunk 45 as p_45.flac
# Saved chunk 46 as p_46.flac
# Saved chunk 47 as p_47.flac
# Saved chunk 47 as p_47.flac
# Saved chunk 48 as p_48.flac
# Saved chunk 49 as p_49.flac
# Saved chunk 49 as p_49.flac
# Saved chunk 50 as p_50.flac
# Saved chunk 51 as p_51.flac
# Saved chunk 51 as p_51.flac
# Saved chunk 52 as p_52.flac
# Saved chunk 53 as p_53.flac
# Saved chunk 54 as p_54.flac
# Saved chunk 54 as p_54.flac
# Saved chunk 55 as p_55.flac
# Saved chunk 55 as p_55.flac
# Saved chunk 56 as p_56.flac
# Saved chunk 57 as p_57.flac
# Saved chunk 58 as p_58.flac
# Saved chunk 58 as p_58.flac
# Saved chunk 59 as p_59.flac
# Saved chunk 60 as p_60.flac
# Saved chunk 60 as p_60.flac
# Saved chunk 61 as p_61.flac
# Saved chunk 61 as p_61.flac
# Saved chunk 62 as p_62.flac
# Saved chunk 62 as p_62.flac
# Saved chunk 63 as p_63.flac
# Saved chunk 64 as p_64.flac
# Saved chunk 65 as p_65.flac
# Saved chunk 66 as p_66.flac
# Saved chunk 66 as p_66.flac
# Saved chunk 67 as p_67.flac
# Saved chunk 68 as p_68.flac
# Saved chunk 68 as p_68.flac
# Saved chunk 69 as p_69.flac
# Saved chunk 69 as p_69.flac
# Saved chunk 70 as p_70.flac
# Saved chunk 71 as p_71.flac
# Saved chunk 71 as p_71.flac
# Saved chunk 72 as p_72.flac
# Saved chunk 73 as p_73.flac
# Saved chunk 73 as p_73.flac
# Saved chunk 74 as p_74.flac
# Saved chunk 74 as p_74.flac
# Saved chunk 75 as p_75.flac
# Saved chunk 76 as p_76.flac
# Saved chunk 76 as p_76.flac
# Saved chunk 77 as p_77.flac
# Saved chunk 77 as p_77.flac
# Saved chunk 78 as p_78.flac
# Saved chunk 78 as p_78.flac
# Saved chunk 79 as p_79.flac
# Saved chunk 79 as p_79.flac
# Saved chunk 80 as p_80.flac
# Saved chunk 80 as p_80.flac
# Saved chunk 81 as p_81.flac
# Saved chunk 82 as p_82.flac
# Saved chunk 82 as p_82.flac
# Saved chunk 83 as p_83.flac
# Saved chunk 84 as p_84.flac
# Saved chunk 84 as p_84.flac
# Saved chunk 85 as p_85.flac
# Saved chunk 86 as p_86.flac
# Saved chunk 86 as p_86.flac
# Saved chunk 87 as p_87.flac
# Saved chunk 88 as p_88.flac
# Saved chunk 88 as p_88.flac
# Saved chunk 89 as p_89.flac
# Saved chunk 89 as p_89.flac
# Saved chunk 90 as p_90.flac
# Saved chunk 90 as p_90.flac
# Saved chunk 91 as p_91.flac
# Saved chunk 92 as p_92.flac
# Saved chunk 92 as p_92.flac
# Saved chunk 93 as p_93.flac
# Saved chunk 93 as p_93.flac
# Saved chunk 94 as p_94.flac
# Saved chunk 95 as p_95.flac
# Saved chunk 95 as p_95.flac
# Saved chunk 96 as p_96.flac
# Saved chunk 97 as p_97.flac
# Saved chunk 98 as p_98.flac
# Saved chunk 98 as p_98.flac
# Saved chunk 99 as p_99.flac
# Saved chunk 99 as p_99.flac
# Saved chunk 100 as p_100.flac
# Saved chunk 100 as p_100.flac
# Saved chunk 101 as p_101.flac
# Saved chunk 101 as p_101.flac
# Saved chunk 102 as p_102.flac
# Saved chunk 103 as p_103.flac
# Saved chunk 104 as p_104.flac
# Saved chunk 105 as p_105.flac
# Saved chunk 106 as p_106.flac
# Saved chunk 107 as p_107.flac
# Saved chunk 108 as p_108.flac
# Saved chunk 109 as p_109.flac
# Saved chunk 109 as p_109.flac
# Saved chunk 110 as p_110.flac
# Saved chunk 110 as p_110.flac
# Saved chunk 111 as p_111.flac
# Saved chunk 112 as p_112.flac
# Saved chunk 112 as p_112.flac
# Saved chunk 113 as p_113.flac
# Saved chunk 114 as p_114.flac
# Saved chunk 115 as p_115.flac
# Saved chunk 115 as p_115.flac
# Saved chunk 116 as p_116.flac
# Saved chunk 116 as p_116.flac
# Saved chunk 117 as p_117.flac
# Saved chunk 117 as p_117.flac
# Saved chunk 118 as p_118.flac
# Saved chunk 119 as p_119.flac
# Saved chunk 119 as p_119.flac
# Saved chunk 120 as p_120.flac
# Saved chunk 120 as p_120.flac
# Saved chunk 121 as p_121.flac
# Saved chunk 122 as p_122.flac
# Saved chunk 123 as p_123.flac
# Saved chunk 124 as p_124.flac
# Saved chunk 125 as p_125.flac
# Saved chunk 126 as p_126.flac
# Saved chunk 127 as p_127.flac
# Saved chunk 128 as p_128.flac
# Saved chunk 129 as p_129.flac
# Saved chunk 130 as p_130.flac
# Saved chunk 131 as p_131.flac
# Saved chunk 132 as p_132.flac
# Saved chunk 133 as p_133.flac
# Saved chunk 133 as p_133.flac
# Saved chunk 134 as p_134.flac
# Saved chunk 135 as p_135.flac
# Saved chunk 136 as p_136.flac
# Saved chunk 136 as p_136.flac
# Saved chunk 137 as p_137.flac
# Saved chunk 138 as p_138.flac
# Saved chunk 139 as p_139.flac
# Saved chunk 140 as p_140.flac
# Saved chunk 141 as p_141.flac
# Saved chunk 142 as p_142.flac
# Saved chunk 143 as p_143.flac
# Saved chunk 144 as p_144.flac
# Saved chunk 145 as p_145.flac
# Saved chunk 146 as p_146.flac
# Saved chunk 146 as p_146.flac
# Saved chunk 147 as p_147.flac
# Saved chunk 148 as p_148.flac
# Saved chunk 149 as p_149.flac
# Saved chunk 149 as p_149.flac
# Saved chunk 150 as p_150.flac
# Saved chunk 151 as p_151.flac
# Saved chunk 152 as p_152.flac
# Saved chunk 153 as p_153.flac
# Saved chunk 154 as p_154.flac
# Saved chunk 154 as p_154.flac
# Saved chunk 155 as p_155.flac
# Saved chunk 155 as p_155.flac
# Saved chunk 156 as p_156.flac
# Saved chunk 156 as p_156.flac
# Saved chunk 157 as p_157.flac
# Saved chunk 158 as p_158.flac
# Saved chunk 158 as p_158.flac
# Saved chunk 159 as p_159.flac
# Saved chunk 160 as p_160.flac
# Saved chunk 161 as p_161.flac
# Saved chunk 161 as p_161.flac
# Saved chunk 162 as p_162.flac
# Saved chunk 163 as p_163.flac
# Saved chunk 163 as p_163.flac
# Saved chunk 164 as p_164.flac
# Saved chunk 165 as p_165.flac
# Saved chunk 165 as p_165.flac
# Saved chunk 166 as p_166.flac
# Saved chunk 166 as p_166.flac
# Saved chunk 167 as p_167.flac
# Saved chunk 167 as p_167.flac
# Saved chunk 168 as p_168.flac
# Saved chunk 168 as p_168.flac
# Saved chunk 169 as p_169.flac
# Saved chunk 169 as p_169.flac
# Saved chunk 170 as p_170.flac
# Saved chunk 171 as p_171.flac
# Saved chunk 172 as p_172.flac
# Saved chunk 173 as p_173.flac
# Saved chunk 174 as p_174.flac
# Saved chunk 174 as p_174.flac
# Saved chunk 175 as p_175.flac
# Saved chunk 175 as p_175.flac
# Saved chunk 176 as p_176.flac
# Saved chunk 177 as p_177.flac
# Saved chunk 177 as p_177.flac
# Saved chunk 178 as p_178.flac
# Saved chunk 179 as p_179.flac
# Saved chunk 179 as p_179.flac
# Saved chunk 180 as p_180.flac
# Saved chunk 180 as p_180.flac
# Saved chunk 181 as p_181.flac
# Saved chunk 181 as p_181.flac
# Saved chunk 182 as p_182.flac
# Saved chunk 183 as p_183.flac
# Saved chunk 184 as p_184.flac
# Saved chunk 185 as p_185.flac
# Saved chunk 186 as p_186.flac
# Saved chunk 186 as p_186.flac
# Saved chunk 187 as p_187.flac
# Saved chunk 187 as p_187.flac
# Saved chunk 188 as p_188.flac
# Chunk 188 is silent and will be skipped.
# Saved chunk 189 as p_189.flac
# Saved chunk 190 as p_190.flac
# Saved chunk 190 as p_190.flac
# Chunk 191 is silent and will be skipped.
# Saved chunk 192 as p_192.flac
# Saved chunk 193 as p_193.flac
# Saved chunk 193 as p_193.flac
# Saved chunk 194 as p_194.flac
# Saved chunk 195 as p_195.flac
# Saved chunk 196 as p_196.flac
# Saved chunk 196 as p_196.flac
# Saved chunk 197 as p_197.flac
# Saved chunk 198 as p_198.flac
# Saved chunk 199 as p_199.flac
# Saved chunk 199 as p_199.flac
# Saved chunk 200 as p_200.flac
# Saved chunk 201 as p_201.flac
# Saved chunk 201 as p_201.flac
# Saved chunk 202 as p_202.flac
# Saved chunk 203 as p_203.flac
# Chunk 204 is silent and will be skipped.
# Saved chunk 205 as p_205.flac
# Saved chunk 206 as p_206.flac
# Saved chunk 206 as p_206.flac
# Saved chunk 207 as p_207.flac
# Saved chunk 208 as p_208.flac
# Saved chunk 209 as p_209.flac
# Saved chunk 209 as p_209.flac
# Saved chunk 210 as p_210.flac
# Saved chunk 211 as p_211.flac
# Saved chunk 212 as p_212.flac
# Saved chunk 213 as p_213.flac
# Chunk 213 is silent and will be skipped.
# Saved chunk 214 as p_214.flac
# Saved chunk 215 as p_215.flac
# Saved chunk 215 as p_215.flac
# Saved chunk 216 as p_216.flac
# Saved chunk 217 as p_217.flac
# Saved chunk 218 as p_218.flac
# Saved chunk 219 as p_219.flac
# Saved chunk 219 as p_219.flac
# Saved chunk 220 as p_220.flac
# Saved chunk 221 as p_221.flac
# Saved chunk 222 as p_222.flac
# Saved chunk 223 as p_223.flac
# Saved chunk 224 as p_224.flac
# Saved chunk 224 as p_224.flac
# Saved chunk 225 as p_225.flac
# Saved chunk 225 as p_225.flac
# Saved chunk 226 as p_226.flac
# Saved chunk 227 as p_227.flac
# Saved chunk 228 as p_228.flac
# Saved chunk 229 as p_229.flac
# Saved chunk 229 as p_229.flac
# Saved chunk 230 as p_230.flac
# Saved chunk 230 as p_230.flac
# Saved chunk 231 as p_231.flac
# Saved chunk 231 as p_231.flac
# Saved chunk 232 as p_232.flac
# Saved chunk 233 as p_233.flac
# Saved chunk 234 as p_234.flac
# Saved chunk 235 as p_235.flac
# Saved chunk 236 as p_236.flac
# Saved chunk 236 as p_236.flac
# Saved chunk 237 as p_237.flac
# Saved chunk 238 as p_238.flac
# Saved chunk 239 as p_239.flac
# Saved chunk 240 as p_240.flac
# Saved chunk 241 as p_241.flac
# Saved chunk 241 as p_241.flac
# Saved chunk 242 as p_242.flac
# Saved chunk 242 as p_242.flac
# Saved chunk 243 as p_243.flac
# Saved chunk 243 as p_243.flac
# Saved chunk 244 as p_244.flac
# Saved chunk 245 as p_245.flac
# Saved chunk 245 as p_245.flac
# Saved chunk 246 as p_246.flac
# Saved chunk 246 as p_246.flac
# Saved chunk 247 as p_247.flac
# Saved chunk 248 as p_248.flac
# Saved chunk 248 as p_248.flac
# Saved chunk 249 as p_249.flac
# Saved chunk 250 as p_250.flac
# Saved chunk 251 as p_251.flac
# Saved chunk 252 as p_252.flac
# Saved chunk 253 as p_253.flac
# Saved chunk 253 as p_253.flac
# Saved chunk 254 as p_254.flac
# Saved chunk 254 as p_254.flac
# Saved chunk 255 as p_255.flac
# Saved chunk 255 as p_255.flac
# Saved chunk 256 as p_256.flac
# Saved chunk 257 as p_257.flac
# Saved chunk 258 as p_258.flac
# Saved chunk 258 as p_258.flac
# Chunk 259 is silent and will be skipped.
# Saved chunk 260 as p_260.flac
# Saved chunk 261 as p_261.flac
# Saved chunk 262 as p_262.flac
# Saved chunk 263 as p_263.flac
# Chunk 264 is silent and will be skipped.
# Saved chunk 265 as p_265.flac
# Saved chunk 266 as p_266.flac
# Saved chunk 266 as p_266.flac
# Saved chunk 267 as p_267.flac
# Saved chunk 268 as p_268.flac
# Saved chunk 269 as p_269.flac
# Saved chunk 270 as p_270.flac
# Saved chunk 271 as p_271.flac
# Chunk 272 is silent and will be skipped.
# Saved chunk 273 as p_273.flac
# Saved chunk 274 as p_274.flac
# Saved chunk 275 as p_275.flac
# Saved chunk 276 as p_276.flac
# Saved chunk 276 as p_276.flac
# Saved chunk 277 as p_277.flac
# Saved chunk 278 as p_278.flac
# Saved chunk 279 as p_279.flac
# Saved chunk 280 as p_280.flac
# Saved chunk 281 as p_281.flac
# Saved chunk 282 as p_282.flac
# Saved chunk 282 as p_282.flac
# Saved chunk 283 as p_283.flac
# Saved chunk 284 as p_284.flac
# Saved chunk 285 as p_285.flac
# Saved chunk 285 as p_285.flac
# Saved chunk 286 as p_286.flac
# Saved chunk 287 as p_287.flac
# Saved chunk 288 as p_288.flac
# Saved chunk 289 as p_289.flac
# Saved chunk 290 as p_290.flac
# Saved chunk 290 as p_290.flac
# Saved chunk 291 as p_291.flac
# Saved chunk 291 as p_291.flac
# Saved chunk 292 as p_292.flac
# Saved chunk 293 as p_293.flac
# Saved chunk 294 as p_294.flac
# Saved chunk 294 as p_294.flac
# Saved chunk 295 as p_295.flac
# Saved chunk 295 as p_295.flac
# Saved chunk 296 as p_296.flac
# Saved chunk 297 as p_297.flac
# Saved chunk 298 as p_298.flac
# Saved chunk 298 as p_298.flac
# Saved chunk 299 as p_299.flac
# Saved chunk 300 as p_300.flac
# Saved chunk 300 as p_300.flac
# Chunk 301 is silent and will be skipped.
# Saved chunk 302 as p_302.flac
# Saved chunk 303 as p_303.flac
# Saved chunk 303 as p_303.flac
# Saved chunk 304 as p_304.flac
# Saved chunk 305 as p_305.flac
# Saved chunk 306 as p_306.flac
# Saved chunk 306 as p_306.flac
# Saved chunk 307 as p_307.flac
# Saved chunk 308 as p_308.flac
# Saved chunk 309 as p_309.flac
# Saved chunk 310 as p_310.flac
# Saved chunk 311 as p_311.flac
# Saved chunk 312 as p_312.flac
# Saved chunk 313 as p_313.flac
# Saved chunk 313 as p_313.flac
# Saved chunk 314 as p_314.flac
# Saved chunk 315 as p_315.flac
# Saved chunk 315 as p_315.flac
# Saved chunk 316 as p_316.flac
# Saved chunk 317 as p_317.flac
# Saved chunk 317 as p_317.flac
# Saved chunk 318 as p_318.flac
# Saved chunk 318 as p_318.flac
# Saved chunk 319 as p_319.flac
# Saved chunk 320 as p_320.flac
# Saved chunk 320 as p_320.flac
# Saved chunk 321 as p_321.flac
# Saved chunk 321 as p_321.flac
# Saved chunk 322 as p_322.flac
# Saved chunk 322 as p_322.flac
# Saved chunk 323 as p_323.flac
# Saved chunk 324 as p_324.flac
# Saved chunk 325 as p_325.flac
# Saved chunk 326 as p_326.flac
# Saved chunk 327 as p_327.flac
# Saved chunk 328 as p_328.flac
# Saved chunk 329 as p_329.flac
# Saved chunk 330 as p_330.flac
# Saved chunk 330 as p_330.flac
# Saved chunk 331 as p_331.flac
# Saved chunk 331 as p_331.flac
# Saved chunk 332 as p_332.flac
# Saved chunk 332 as p_332.flac
# Saved chunk 333 as p_333.flac
# Saved chunk 333 as p_333.flac
# Saved chunk 334 as p_334.flac
# Saved chunk 334 as p_334.flac
# Saved chunk 335 as p_335.flac
# Saved chunk 335 as p_335.flac
# Saved chunk 336 as p_336.flac
# Saved chunk 336 as p_336.flac
# Saved chunk 337 as p_337.flac
# Saved chunk 338 as p_338.flac
# Saved chunk 338 as p_338.flac
# Saved chunk 339 as p_339.flac
# Saved chunk 339 as p_339.flac
# Saved chunk 340 as p_340.flac
# Saved chunk 341 as p_341.flac
# Saved chunk 341 as p_341.flac
# Saved chunk 342 as p_342.flac
# Saved chunk 342 as p_342.flac
# Saved chunk 343 as p_343.flac
# Saved chunk 344 as p_344.flac
# Saved chunk 344 as p_344.flac
# Saved chunk 345 as p_345.flac
# Saved chunk 346 as p_346.flac
# Saved chunk 347 as p_347.flac
# Saved chunk 347 as p_347.flac
# Saved chunk 348 as p_348.flac
# Saved chunk 349 as p_349.flac
# Saved chunk 349 as p_349.flac
# Saved chunk 350 as p_350.flac
# Chunk 351 is silent and will be skipped.
# Saved chunk 352 as p_352.flac
# Saved chunk 353 as p_353.flac
# Saved chunk 353 as p_353.flac
# Saved chunk 354 as p_354.flac
# Saved chunk 354 as p_354.flac
# Saved chunk 355 as p_355.flac
# Saved chunk 355 as p_355.flac
# Saved chunk 356 as p_356.flac
# Saved chunk 357 as p_357.flac
# Saved chunk 358 as p_358.flac
# Saved chunk 358 as p_358.flac
# Saved chunk 359 as p_359.flac
# Saved chunk 360 as p_360.flac
# Saved chunk 361 as p_361.flac
# Saved chunk 362 as p_362.flac
# Saved chunk 363 as p_363.flac
# Saved chunk 363 as p_363.flac
# Saved chunk 364 as p_364.flac
# Saved chunk 365 as p_365.flac
# Saved chunk 366 as p_366.flac
# Saved chunk 367 as p_367.flac
# Saved chunk 368 as p_368.flac
# Saved chunk 369 as p_369.flac
# Saved chunk 369 as p_369.flac
# Saved chunk 370 as p_370.flac
# Saved chunk 370 as p_370.flac
# Saved chunk 371 as p_371.flac
# Saved chunk 372 as p_372.flac
# Saved chunk 373 as p_373.flac
# Saved chunk 374 as p_374.flac
# Saved chunk 375 as p_375.flac
# Saved chunk 376 as p_376.flac
# Saved chunk 376 as p_376.flac
# Saved chunk 377 as p_377.flac
# Saved chunk 378 as p_378.flac
# Saved chunk 379 as p_379.flac
# Saved chunk 380 as p_380.flac
# Saved chunk 381 as p_381.flac
# Saved chunk 381 as p_381.flac
# Saved chunk 382 as p_382.flac
# Saved chunk 383 as p_383.flac
# Saved chunk 384 as p_384.flac
# Saved chunk 385 as p_385.flac
# Saved chunk 386 as p_386.flac
# Saved chunk 387 as p_387.flac
# Saved chunk 388 as p_388.flac
# Saved chunk 389 as p_389.flac
# Saved chunk 390 as p_390.flac
# Saved chunk 390 as p_390.flac
# Saved chunk 391 as p_391.flac
# Saved chunk 392 as p_392.flac
# Saved chunk 392 as p_392.flac
# Saved chunk 393 as p_393.flac
# Saved chunk 393 as p_393.flac
# Saved chunk 394 as p_394.flac
# Saved chunk 394 as p_394.flac
# Saved chunk 395 as p_395.flac
# Saved chunk 395 as p_395.flac
# Saved chunk 396 as p_396.flac
# Saved chunk 396 as p_396.flac
# Saved chunk 397 as p_397.flac
# Saved chunk 397 as p_397.flac
# Saved chunk 398 as p_398.flac
# Saved chunk 398 as p_398.flac
# Saved chunk 399 as p_399.flac
# Saved chunk 400 as p_400.flac
# Saved chunk 400 as p_400.flac
# Saved chunk 401 as p_401.flac
# Saved chunk 402 as p_402.flac
# Saved chunk 402 as p_402.flac
# Saved chunk 403 as p_403.flac
# Saved chunk 403 as p_403.flac
# Saved chunk 404 as p_404.flac
# Saved chunk 404 as p_404.flac
# Saved chunk 405 as p_405.flac
# Saved chunk 405 as p_405.flac
# Saved chunk 406 as p_406.flac
# Saved chunk 406 as p_406.flac
# Saved chunk 407 as p_407.flac
# Saved chunk 407 as p_407.flac
# Saved chunk 408 as p_408.flac
# Saved chunk 408 as p_408.flac
# Saved chunk 409 as p_409.flac
# Saved chunk 409 as p_409.flac
# Saved chunk 410 as p_410.flac
# Saved chunk 410 as p_410.flac
# Saved chunk 411 as p_411.flac
# Saved chunk 411 as p_411.flac
# Saved chunk 412 as p_412.flac
# Saved chunk 413 as p_413.flac
# Saved chunk 414 as p_414.flac
# Saved chunk 415 as p_415.flac
# Saved chunk 416 as p_416.flac
# Saved chunk 417 as p_417.flac
# Saved chunk 417 as p_417.flac
# Saved chunk 418 as p_418.flac
# Saved chunk 419 as p_419.flac
# Saved chunk 420 as p_420.flac
# Saved chunk 421 as p_421.flac
# Saved chunk 421 as p_421.flac
# Saved chunk 422 as p_422.flac
# Saved chunk 423 as p_423.flac
# Saved chunk 424 as p_424.flac
# Saved chunk 425 as p_425.flac
# Saved chunk 426 as p_426.flac
# Saved chunk 427 as p_427.flac
# Saved chunk 428 as p_428.flac
# Saved chunk 428 as p_428.flac
# Saved chunk 429 as p_429.flac
# Saved chunk 429 as p_429.flac
# Saved chunk 430 as p_430.flac
# Saved chunk 431 as p_431.flac
# Saved chunk 432 as p_432.flac
# Saved chunk 433 as p_433.flac
# Saved chunk 433 as p_433.flac
# Saved chunk 434 as p_434.flac
# Saved chunk 434 as p_434.flac
# Saved chunk 435 as p_435.flac
# Saved chunk 436 as p_436.flac
# Saved chunk 437 as p_437.flac
# Saved chunk 438 as p_438.flac
# Saved chunk 439 as p_439.flac
# Saved chunk 440 as p_440.flac
# Saved chunk 441 as p_441.flac
# Saved chunk 442 as p_442.flac
# Saved chunk 443 as p_443.flac
# Saved chunk 444 as p_444.flac
# Saved chunk 444 as p_444.flac
# Saved chunk 445 as p_445.flac
# Saved chunk 446 as p_446.flac
# Saved chunk 447 as p_447.flac
# Saved chunk 448 as p_448.flac
# Saved chunk 448 as p_448.flac
# Saved chunk 449 as p_449.flac
# Saved chunk 449 as p_449.flac
# Saved chunk 450 as p_450.flac
# Saved chunk 451 as p_451.flac
# Saved chunk 452 as p_452.flac
# Saved chunk 453 as p_453.flac
# Saved chunk 454 as p_454.flac
# Saved chunk 455 as p_455.flac
# Saved chunk 456 as p_456.flac
# Saved chunk 456 as p_456.flac
# Saved chunk 457 as p_457.flac
# Saved chunk 458 as p_458.flac
# Saved chunk 459 as p_459.flac
# Saved chunk 460 as p_460.flac
# Saved chunk 460 as p_460.flac
# Saved chunk 461 as p_461.flac
# Saved chunk 462 as p_462.flac
# Saved chunk 463 as p_463.flac
# Saved chunk 464 as p_464.flac
# Saved chunk 465 as p_465.flac
# Saved chunk 466 as p_466.flac
# Saved chunk 467 as p_467.flac
# Saved chunk 468 as p_468.flac
# Saved chunk 469 as p_469.flac
# Saved chunk 469 as p_469.flac
# Saved chunk 470 as p_470.flac
# Chunk 470 is silent and will be skipped.
# Saved chunk 471 as p_471.flac
# Saved chunk 472 as p_472.flac
# Saved chunk 473 as p_473.flac
# Saved chunk 473 as p_473.flac
# Saved chunk 474 as p_474.flac
# Saved chunk 474 as p_474.flac
# Saved chunk 475 as p_475.flac
# Saved chunk 476 as p_476.flac
# Saved chunk 476 as p_476.flac
# Saved chunk 477 as p_477.flac
# Saved chunk 478 as p_478.flac
# Saved chunk 479 as p_479.flac
# Saved chunk 480 as p_480.flac
# Saved chunk 480 as p_480.flac
# Saved chunk 481 as p_481.flac
# Saved chunk 482 as p_482.flac
# Saved chunk 483 as p_483.flac
# Saved chunk 484 as p_484.flac
# Saved chunk 485 as p_485.flac
# Saved chunk 486 as p_486.flac
# Saved chunk 487 as p_487.flac
# Saved chunk 488 as p_488.flac
# Saved chunk 488 as p_488.flac
# Saved chunk 489 as p_489.flac
# Saved chunk 489 as p_489.flac
# Saved chunk 490 as p_490.flac
# Saved chunk 491 as p_491.flac
# Saved chunk 491 as p_491.flac
# Saved chunk 492 as p_492.flac
# Saved chunk 492 as p_492.flac

# %%
# !pip install webrtcvad
# The webrtcvad module needs to be installed.
# Out:
# Collecting webrtcvad
#   Downloading webrtcvad-2.0.10.tar.gz (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 761.6 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: webrtcvad
#   Building wheel for webrtcvad (setup.py) ... done
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp310-cp310-linux_x86_64.whl size=73461 sha256=6877c8c6eb3450078a0230ad26753b084a06863d85719201244d34c5e3473515
#   Stored in directory: /root/.cache/pip/wheels/2a/2b/84/ac7bacfe8c68a87c1ee3dd3c66818a54c71599abf308e8eb35
# Successfully built webrtcvad
# Installing collected packages: webrtcvad
# Successfully installed webrtcvad-2.0.10
